# %% [markdown]
# # Collection Exploration Notebook
# This notebook contains tools for exploring the contents of your web archive derivatives.

# %% [markdown]
# ### Mount Google Drive
# In order to persist working files/data across multiple runs of the notebook.

# %%
from google.colab import drive 
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ### Load AOYTK
#
# Downloads and imports the All Our Yesterdays Toolkit

# %%
# !wget "https://raw.githubusercontent.com/BrockDSL/AOYTK/SL/aoytk.py"
import aoytk

# %% [markdown]
# ### Set Working Directory
# Select a working folder for reading and writing data. By default, this path will be set to `/content/drive/MyDrive/AOY/`.

# %%
aoytk.display_path_select()
# Out:
# Text(value='/content/drive/MyDrive/AOY/', description='Folder path:', placeholder='Enter your folder path')
# Button(description='Submit', style=ButtonStyle())
# Folder path set to: C:/Users/Sam/Desktop/AOY-Data

# %% [markdown]
# ## Data Exploration
# The following cells provide tools for exploring web-archive derivatives (which are saved in the working folder selected in the setup stage).
#
# We'll start by creating our Analyzer!

# %%
# initialize the analyzer
atk = aoytk.Analyzer()

# %% [markdown]
# Now we can select the web-archive derivative we want to work with.

# %%
atk.load_data()
# Out:
# HBox(children=(Label(value='Derivative file to analyze '), Dropdown(options=('niagara_sample.csv',), value='ni…
# Button(description='Select file', style=ButtonStyle())
# Loading data...
# Data loaded from: C:/Users/Sam/Desktop/AOY-Data/niagara_sample.csv

# %% [markdown]
# ## Domain Frequencies

# %%
atk.display_top_domains()
# Out:
# There are 301 different domains in the dataset.
# IntSlider(value=10, max=301)
# Output()

# %% [markdown]
# ## Crawl Frequency

# %%
atk.display_crawl_frequency()
# Out:
# HBox(children=(Label(value='Number of domains: '), IntSlider(value=10, max=12, min=1)))
# HBox(children=(Label(value='Style of visualization: '), RadioButtons(options=('3D', '2D'), value='3D')))
# HBox(children=(VBox(children=(Label(value='Select a start date  '), Label(value='Select an end date '), Label(…
# Button(description='Create visualization', style=ButtonStyle())
# HBox(children=(Label(value='Number of domains: '), IntSlider(value=10, max=12, min=1)))
# HBox(children=(Label(value='Style of visualization: '), RadioButtons(options=('3D', '2D'), value='3D')))
# HBox(children=(VBox(children=(Label(value='Select a start date  '), Label(value='Select an end date '), Label(…
# Button(description='Create visualization', style=ButtonStyle())
# Creating visualization...
