# %% [markdown]
# <a href="https://colab.research.google.com/github/BrockDSL/AOYTK/blob/main/AOY_Text_Topic_Modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![AOY Logo](https://raw.githubusercontent.com/BrockDSL/AOYTK/main/AOY_Logo.png)
#
# # All Our Yesterdays
#
# A [toolkit](https://brockdsl.github.io/AOTYK) to explore web archives.
#
#
# ## Topic Modelling
#
# This notebook will open a derivative csv file and go through the basic setup and execution of an LDA topic model using SciKit

# %%
#Set Environment
print("Setting up AOYTK please wait...")

# !pip -q install pyLDAvis
# !wget "https://raw.githubusercontent.com/BrockDSL/AOYTK/main/aoytk.py"
import pandas as pd
import gensim
import pyLDAvis
import pyLDAvis.gensim_models
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from google.colab import drive 

import aoytk

#Bootstap environment
drive.mount("/content/drive/")


#additions to aoytk
from IPython.display import clear_output
clear_output()

### 

print("Select the Derivate file to work from")
atk = aoytk.Analyzer()
atk.load_data()
# Out:
# Select the Derivate file to work from
# Dropdown(description='Derivative file:', options=('niagara_sample.csv', 'nigara_feb_27.csv'), value='niagara_s…
# Button(description='Select file', style=ButtonStyle())
# File chosen: /content/drive/MyDrive/AOY//niagara_sample.csv

# %%
#Data Set is accessible via
atk.data
# Out:
#       crawl_date         domain  \
# 0       20210219         cbc.ca
# 1       20210226  pinterest.com
# 2       20210116      brocku.ca
# 3       20201205        gncc.ca
# 4       20210522      brocku.ca
# ...          ...            ...
# 4995    20201017      brocku.ca
# 4996    20210116      brocku.ca
# 4997    20200704      brocku.ca
# 4998    20200718      brocku.ca
# 4999    20211204      brocku.ca
#
#                                                     url mime_type_web_server  \
# 0                            https://www.cbc.ca/sitemap            text/html
# 1      https://www.pinterest.com/tuocproaudio/cd-audio/            text/html
# 2     https://discover.brocku.ca/event-registration/...            text/html
# 3     https://gncc.ca/community-event/autism-awarene...            text/html
# 4     https://exhibits.library.brocku.ca/s/COVID-Nia...            text/html
# ...                                                 ...                  ...
# 4995  https://exhibits.library.brocku.ca/s/COVID-Nia...            text/html
# 4996  https://discover.brocku.ca/event-registration/...            text/html
# 4997  https://exhibits.library.brocku.ca/s/COVID-Nia...            text/html
# 4998  https://exhibits.library.brocku.ca/s/COVID-Nia...            text/html
# 4999  https://exhibits.library.brocku.ca/s/COVID-Nia...            text/html
#
#      mime_type_tika language  \
# 0         text/html       en
# 1         text/html       en
# 2         text/html       en
# 3         text/html       en
# 4               NaN      NaN
# ...             ...      ...
# 4995            NaN      NaN
# 4996      text/html       en
# 4997      text/html       en
# 4998            NaN      NaN
# 4999            NaN      NaN
#
#                                                 content
# 0     Skip to Main Content Menu Search Search Sign I...
# 1     CD audio CD audio Collection by THÙNG LOA ĐẸP ...
# 2     Register for events – Discover Brock Universit...
# 3     Autism Awareness BBQ - Greater Niagara Chamber...
# 4                                                   NaN
# ...                                                 ...
# 4995                                                NaN
# 4996  Register for events – Discover Brock Universit...
# 4997  5E4A65F3-8372-4192-912D-0F8D9C45CEAE.jpeg · Do...
# 4998                                                NaN
# 4999                                                NaN
#
# [5000 rows x 7 columns]

# %% [markdown]
# ## Prepare Texts
#
# Run the following Cell to prepare the webpage text for modelling.

# %% [markdown]
# ## Build Models
#
# Run the next cell to build the LDA model and see a basic visualization of it

# %%
#Model parameters

NUM_TOPICS = 19            #default 100


#
ALPHA ='auto'             #default 'symmetric'
CHUNKSIZE = 100           #default 2000
COHERENCE_METHOD = 'c_v'
ITERATIONS = 200          #default 50
PASSES = 10               #default 1
PER_WORD_TOPICS = False   #default False
RANDOM_STATE = 100
UPDATE_EVERY = 1          #default 1
TOPICS_TO_SHOW = 15

#Generate Model and get basic dynamics of it
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,\
                                                id2word=id2word,\
                                                num_topics=NUM_TOPICS,\
                                                random_state = RANDOM_STATE,\
                                                update_every = UPDATE_EVERY,\
                                                chunksize = CHUNKSIZE,\
                                                passes = PASSES,\
                                                alpha = ALPHA,\
                                                iterations = ITERATIONS,\
                                                per_word_topics = PER_WORD_TOPICS)

coherence_model_lda = CoherenceModel(model=lda_model, texts=texts, dictionary=id2word, coherence = COHERENCE_METHOD)
#print("Perplexity: ", lda_model.log_perplexity(corpus))
#print("Coherence: ", coherence_model_lda.get_coherence())

pyLDAvis.enable_notebook()
#Projection parameter
# tsne
# mmds
# pcoa
vis = pyLDAvis.gensim_models.prepare(lda_model,corpus,id2word,mds="mmds")
vis

# %%
#Power down Dev Environment - Deleted this cell when finalized

from google.colab import files
files.download('aoytk.py')
